# %% [markdown]
# Here we will be implementing and visualizing the cost function for linear regression with one variable. In this lab, we will be using NumPy (a popular library for scientific computing) and Matplotlib (a popular library for plotting data).

# %%
import numpy as np

# %matplotlib widget
import matplotlib.pyplot as plt

from jupyter_utils_unique import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl

plt.style.use("./deeplearning.mplstyle")

# %% [markdown]
# Problem Statement: You would like a model which can predict housing prices given the size of the house. Let's use the data points: a house with 1000 square feet sold for $300,000 and a house with 2000 square feet sold for $500,000.

# %%
x_train = np.array([1.0, 2.0])
y_train = np.array([300.0, 500.0])

# %%
def compute_cost(x, y, w, b):
    """
    Computes the cost function for linear regression.

    Args:
        x (ndarray (m,)): data, m examples.
        y (ndarray (m,)): target values.
        w, b (scalar): model parameters.

    Returns:
        total_cost (float): the cost of using w, b as the parameters for linear regression 
        to fit the data points in x and y.
    """

    # Number of training examples.
    m = x.shape[0]

    cost_sum = 0
    for i in range(m):
        f_wb = w * x[i] + b
        cost = (f_wb - y[i]) ** 2
        cost_sum = cost_sum + cost
    total_cost = (1 / (2 * m)) * cost_sum

    return total_cost

# %%
plt_intuition(x_train, y_train)
# Out:
# interactive(children=(IntSlider(value=150, description='w', max=400, step=10), Output()), _dom_classes=('widge…

# %% [markdown]
# A Larger Data Set: It is instructive to view a scenario with a few more data points. This data set includes data points that do not fall on the same line. What does that mean for the cost equation? Can we find w and b that will give us a cost of 0?

# %%
x_train = np.array([1.0, 1.7, 2.0, 2.5, 3.0, 3.2])
y_train = np.array([250, 300, 480, 430, 630, 730])

# %%
plt.close("all")
fig, ax, dyn_items = plt_stationary(x_train, y_train)
updater = plt_update_onclick(fig, ax, x_train, y_train, dyn_items)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Above, note the dashed lines in the left plot. These represent the portion of the cost contributed by each example in your training set. In this case, values of approximately w = 209 and b = 2.4 provide low cost. Note that, because our training examples are not on a line, the minimum cost is not 0.

# %%
soup_bowl()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
