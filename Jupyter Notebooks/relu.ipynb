# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
plt.style.use("./deeplearning.mplstyle")

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU
from tensorflow.keras.activations import linear, relu, sigmoid
# %matplotlib widget

from matplotlib.widgets import Slider
from jupyter_utils_common import dlc
from autils import plt_act_trio
from jupyter_utils_relu import *

import warning
warnings.simplefilter(action="ignore", category=UserWarning)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 14
#      12 from matplotlib.widgets import Slider
#      13 from jupyter_utils_common import dlc
# ---> 14 from autils import plt_act_trio
#      15 from jupyter_utils_relu import *
#      17 import warning
#
# ModuleNotFoundError: No module named 'autils'
